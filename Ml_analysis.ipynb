# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load the Data

# %%
df = pd.read_csv("Student Social Media And Mental Health Impact.csv")

# %% [markdown]
# ## Basic information of Data

# %%
# 5 first rows
df.head()
# Out:
#    Age  Gender Country  ... Sleep_Hours_Per_Night Stress_Level Mental_Health_Score
# 0   21    Male   Other  ...                   6.7       Medium                 6.8
# 1   23  Female   Other  ...                   8.6          Low                 7.6
# 2   22    Male  Canada  ...                   6.7       Medium                 7.0
# 3   18    Male   Other  ...                   5.4    Very High                 5.3
# 4   24  Female   Other  ...                   5.0    Very High                 4.4
#
# [5 rows x 13 columns]

# %%
# number of rows and columns
df.shape
# Out:
# (5000, 13)

# %%
# columns name
df.columns
# Out:
# Index(['Age', 'Gender', 'Country', 'Academic_Level', 'Most_Used_Platform',
#        'Purpose_Of_Use', 'Avg_Daily_Usage_Hours', 'Daily_Unlocks',
#        'Study_Hours', 'Physical_Activity_Hours', 'Sleep_Hours_Per_Night',
#        'Stress_Level', 'Mental_Health_Score'],
#       dtype='str')

# %%
# check null
df.isnull().sum()
# Out:
# Age                        0
# Gender                     0
# Country                    0
# Academic_Level             0
# Most_Used_Platform         0
# Purpose_Of_Use             0
# Avg_Daily_Usage_Hours      0
# Daily_Unlocks              0
# Study_Hours                0
# Physical_Activity_Hours    0
# Sleep_Hours_Per_Night      0
# Stress_Level               0
# Mental_Health_Score        0
# dtype: int64

# %%
# Duplicated vlaue
df.duplicated().sum()
# Out:
# np.int64(2)

# %%
# info of the data
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      5000 non-null   int64
#  1   Gender                   5000 non-null   str
#  2   Country                  5000 non-null   str
#  3   Academic_Level           5000 non-null   str
#  4   Most_Used_Platform       5000 non-null   str
#  5   Purpose_Of_Use           5000 non-null   str
#  6   Avg_Daily_Usage_Hours    5000 non-null   float64
#  7   Daily_Unlocks            5000 non-null   int64
#  8   Study_Hours              5000 non-null   float64
#  9   Physical_Activity_Hours  5000 non-null   float64
#  10  Sleep_Hours_Per_Night    5000 non-null   float64
#  11  Stress_Level             5000 non-null   str
#  12  Mental_Health_Score      5000 non-null   float64
# dtypes: float64(5), int64(2), str(6)
# memory usage: 507.9 KB

# %%
# describes of Numeric Data
df.describe()
# Out:
#               Age  ...  Mental_Health_Score
# count  5000.00000  ...          5000.000000
# mean     20.82180  ...             6.230980
# std       1.73662  ...             1.278701
# min      18.00000  ...             3.600000
# 25%      19.00000  ...             5.100000
# 50%      21.00000  ...             6.100000
# 75%      22.00000  ...             7.100000
# max      24.00000  ...             9.400000
#
# [8 rows x 7 columns]

# %%
# Describes of category Data
df.describe(include=object)
# Out:
# C:\Users\aahes\AppData\Local\Temp\ipykernel_20608\2869196876.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include=object)
#        Gender Country  ... Purpose_Of_Use Stress_Level
# count    5000    5000  ...           5000         5000
# unique      2     111  ...              4            4
# top      Male   Other  ...  Entertainment    Very High
# freq     2635    1880  ...           2552         1621
#
# [4 rows x 6 columns]

# %% [markdown]
# ## EDA

# %%
## Distributuion  of the target (mental_health_score)
sns.histplot(df['Mental_Health_Score'], kde=True)
plt.title("Distribution of Mental Health Score")
plt.show()

# %%
#3 Correaltion Heatmap only on Numeric Cols
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.title("Correlation Of Numeric Cols")
plt.show()

# %%
## stress_level vs mental_health_Score
df['Stress_Level'].unique()
# Out:
# <StringArray>
# ['Medium', 'Low', 'Very High', 'High']
# Length: 4, dtype: str

# %%
order = ['Low','Medium','High','Very High']
sns.boxplot(x='Stress_Level', y='Mental_Health_Score', data=df, order=order)
plt.xlabel('Stree_level')
plt.ylabel('Mental_Health_Score')
plt.title("stress_level vs mental_health_Score")
plt.show()

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Country', 'Academic_Level', 'Most_Used_Platform',
#        'Purpose_Of_Use', 'Avg_Daily_Usage_Hours', 'Daily_Unlocks',
#        'Study_Hours', 'Physical_Activity_Hours', 'Sleep_Hours_Per_Night',
#        'Stress_Level', 'Mental_Health_Score'],
#       dtype='str')

# %%
# daily_usage_hours vs mental_health_score
sns.scatterplot(x='Avg_Daily_Usage_Hours', y='Mental_Health_Score', data=df)
plt.xlabel('Avg_Daily_Usage_Hours')
plt.ylabel('Mental_Health_Score')
plt.title("Avg_Daily_Usage_Hours vs mental_health_Score")
plt.show()

# %%
# sleep_hours vs mental_health_score
sns.scatterplot(x='Sleep_Hours_Per_Night', y='Mental_Health_Score', data=df)
plt.xlabel('Sleep_Hours_Per_Night')
plt.ylabel('Mental_Health_Score')
plt.title("Sleep_Hours_Per_Night vs mental_health_Score")
plt.show()

# %%
# most used platform
platform_count = df['Most_Used_Platform'].value_counts()
platform_count
# Out:
# Most_Used_Platform
# Instagram    1130
# TikTok        918
# Facebook      719
# LinkedIn      523
# YouTube       491
# Twitter       462
# Snapchat      420
# WhatsApp      175
# LINE           50
# VKontakte      40
# KakaoTalk      36
# WeChat         36
# Name: count, dtype: int64

# %%
sns.countplot(x=df['Most_Used_Platform'], order=df['Most_Used_Platform'].value_counts().index )
plt.xticks(rotation=90)
plt.title("Most used platform")
plt.show()

# %% [markdown]
# ## Checking Outliers

# %%
num_features = df.select_dtypes(include="number")

# %%
Q1 = num_features.quantile(0.25)
Q3 = num_features.quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = (num_features < lower_bound) | (num_features > upper_bound)
outliers.sum()
# Out:
# Age                         0
# Avg_Daily_Usage_Hours       0
# Daily_Unlocks               0
# Study_Hours                 2
# Physical_Activity_Hours    22
# Sleep_Hours_Per_Night       0
# Mental_Health_Score         0
# dtype: int64

# %% [markdown]
# ## Data Cleaning

# %%
df.duplicated().sum()
# Out:
# np.int64(2)

# %%
## To Drop Duplicated
df = df.drop_duplicates()

## Converting negative values or unrealistic values to realistic values
df['Physical_Activity_Hours'] = df['Physical_Activity_Hours'].clip(lower=0)

# %%
df.describe()
# Out:
#                Age  ...  Mental_Health_Score
# count  4998.000000  ...          4998.000000
# mean     20.822129  ...             6.231152
# std       1.736774  ...             1.278476
# min      18.000000  ...             3.600000
# 25%      19.000000  ...             5.100000
# 50%      21.000000  ...             6.100000
# 75%      22.000000  ...             7.100000
# max      24.000000  ...             9.400000
#
# [8 rows x 7 columns]

# %% [markdown]
# ## Skewness

# %%
num_features.skew()
#near to 0 -> centeraliszed
# negative ->  left skew
# positive (gt than 0) -> right skew
# Out:
# Age                        0.155325
# Avg_Daily_Usage_Hours      0.005606
# Daily_Unlocks              0.002351
# Study_Hours                0.435819
# Physical_Activity_Hours    0.039971
# Sleep_Hours_Per_Night      0.124050
# Mental_Health_Score        0.206567
# dtype: float64

# %% [markdown]
# ## Feature Engineering

# %%
df.head()
# Out:
#    Age  Gender Country  ... Sleep_Hours_Per_Night Stress_Level Mental_Health_Score
# 0   21    Male   Other  ...                   6.7       Medium                 6.8
# 1   23  Female   Other  ...                   8.6          Low                 7.6
# 2   22    Male  Canada  ...                   6.7       Medium                 7.0
# 3   18    Male   Other  ...                   5.4    Very High                 5.3
# 4   24  Female   Other  ...                   5.0    Very High                 4.4
#
# [5 rows x 13 columns]

# %%
top_countries = df['Country'].value_counts().index[:10].to_list()  #we only get top 10 countries and oter are store in the other

# %%
def group_countries(country):

    if country in top_countries:
        return country
    else:
        return 'Other'

# %%
#apply on df['Country]
df['Grouped_Country'] = df['Country'].apply(group_countries)

# %%
df['Grouped_Country'].value_counts()
# Out:
# Grouped_Country
# Other        3231
# India         389
# USA           354
# Canada        230
# Australia     198
# UK            185
# Germany       136
# Mexico         94
# Turkey         94
# France         87
# Name: count, dtype: int64

# %% [markdown]
# ## Encoding Strategy

# %% [markdown]
# ###### Apply ordinal encoding on Stress_level

# %% [markdown]
# ## Train and Split

# %%
num_features.columns
# Out:
# Index(['Age', 'Avg_Daily_Usage_Hours', 'Daily_Unlocks', 'Study_Hours',
#        'Physical_Activity_Hours', 'Sleep_Hours_Per_Night',
#        'Mental_Health_Score'],
#       dtype='str')

# %%
df.describe(include=object)
# Out:
# C:\Users\aahes\AppData\Local\Temp\ipykernel_20608\3998025828.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include=object)
#        Gender Country  ... Stress_Level Grouped_Country
# count    4998    4998  ...         4998            4998
# unique      2     111  ...            4              10
# top      Male   Other  ...    Very High           Other
# freq     2634    1879  ...         1621            3231
#
# [4 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split

skewed_cols   = ['Study_Hours']
other_numeric_cols = ['Age', 'Avg_Daily_Usage_Hours', 'Daily_Unlocks',
                     'Physical_Activity_Hours', 'Sleep_Hours_Per_Night']
ordinal_col  = ['Stress_Level']
normal_col = [ 'Gender', 'Academic_Level', 'Most_Used_Platform','Purpose_Of_Use', 'Grouped_Country']


feature_col = skewed_cols + other_numeric_cols + ordinal_col + normal_col
X = df[feature_col]
y = df['Mental_Health_Score']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %% [markdown]
# ## Preprocessing using Column Transformer

# %%
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer, StandardScaler, OrdinalEncoder ,OneHotEncoder
from sklearn.compose import ColumnTransformer

# 1. skewed features
skew_pipeline  = Pipeline(steps=[
    ('log_transform', FunctionTransformer(np.log1p)),
    ('scalar', StandardScaler())
])

# 2. Numeric Feature
plain_numeric_pipeline = Pipeline(steps=[
    ('scale', StandardScaler())
])

# 3. Ordinal
ordinal_pipeline = Pipeline(steps=[
    ('encoder', OrdinalEncoder(categories=[['Low','Medium','High','Very High']]))
])


# 4. Nominal Features
nominal_pipeline = Pipeline(steps=[
    ('encode', OneHotEncoder(handle_unknown='ignore'))
])

#(konsi_pipeline, konsa_features)
preprocessor = ColumnTransformer(transformers=[
    ('Skewed_pipeline', skew_pipeline, skewed_cols),
    ('Plain_Numeric', plain_numeric_pipeline, other_numeric_cols),
    ('Ordinal', ordinal_pipeline, ordinal_col),
    ('Normal', nominal_pipeline,normal_col)
])

# %% [markdown]
# ## Model Building

# %%
X_train.columns.to_list()
# Out:
# ['Study_Hours',
#  'Age',
#  'Avg_Daily_Usage_Hours',
#  'Daily_Unlocks',
#  'Physical_Activity_Hours',
#  'Sleep_Hours_Per_Night',
#  'Stress_Level',
#  'Gender',
#  'Academic_Level',
#  'Most_Used_Platform',
#  'Purpose_Of_Use',
#  'Grouped_Country']

# %% [markdown]
# #### Baseline: Linear Refression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

lr_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

lr_pipeline.fit(X_train,y_train)
lr_preds = lr_pipeline.predict(X_test)
lr_preds_train = lr_pipeline.predict(X_train)

lr_r2_testing= r2_score(y_test,lr_preds)
lr_r2_training = r2_score(y_train, lr_preds_train)
lr_mae = mean_absolute_error(y_test, lr_preds)

print(f"Accuracy of Trainig : {lr_r2_training}")
print(f"Accuracy of Testing : {lr_r2_testing}")
print(f"MAE: {lr_mae}")
# Out:
# Accuracy of Trainig : 0.7236771199387539
# Accuracy of Testing : 0.7397944617433021
# MAE: 0.5361775634720182

# %% [markdown]
# #### Random forest(default Setting)

# %%
from sklearn.ensemble import RandomForestRegressor

rf_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('randomforest', RandomForestRegressor(random_state=42))
])

rf_pipeline.fit(X_train,y_train)
rf_preds = rf_pipeline.predict(X_test)
rf_preds_train = rf_pipeline.predict(X_train)

rf_r2_testing= r2_score(y_test,rf_preds)
rf_r2_training = r2_score(y_train, rf_preds_train)
rf_mae = mean_absolute_error(y_test, rf_preds)

print(f"Accuracy of Trainig : {rf_r2_training}")
print(f"Accuracy of Testing : {rf_r2_testing}")
print(f"MAE: {rf_mae}")
# Out:
# Accuracy of Trainig : 0.9809069341581819
# Accuracy of Testing : 0.8780167461546369
# MAE: 0.34650236666666673

# %% [markdown]
# #### Hyperparameter Tuning the Random forest

# %%
from sklearn.model_selection import RandomizedSearchCV

param_grid = {
    'randomforest__n_estimators'       :[100,200,300,400,500],
    'randomforest__max_depth'         :[5,10,15,20,25],
    'randomforest__min_samples_split' :[2,5,10,15,20],
    'randomforest__min_samples_leaf'  :[1,2,4,6,8]
}   

random_search = RandomizedSearchCV(
    estimator=rf_pipeline,
    param_distributions= param_grid,
    n_iter= 15,
    cv= 5,
    scoring= 'r2',
    random_state=42,
    n_jobs= -1 #free Processor work
)

random_search.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(transformers=[('Skewed_pipeline',
#                                                                                Pipeline(steps=[('log_transform',
#                                                                                                 FunctionTransformer(func=<ufunc 'log1p'>)),
#                                                                                                ('scalar',
#                                                                                                 StandardScaler())]),
#                                                                                ['Study_Hours']),
#                                                                               ('Plain_Numeric',
#                                                                                Pipeline(steps=[('scale',
# ...

# %%
random_search.best_params_
# Out:
# {'randomforest__n_estimators': 300,
#  'randomforest__min_samples_split': 2,
#  'randomforest__min_samples_leaf': 2,
#  'randomforest__max_depth': 25}

# %%
rf_best_pipeline = random_search.best_estimator_
rf_best_preds = rf_best_pipeline.predict(X_test)

print(f"R2 score for random forest after hyperparameter tunung {r2_score(y_test,rf_best_preds)}")
print(f"MAE for random forest after hyperparameter tunung {mean_absolute_error(y_test,rf_best_preds)}")
# Out:
# R2 score for random forest after hyperparameter tunung 0.8706429326017081
# MAE for random forest after hyperparameter tunung 0.35780953066396115

# %% [markdown]
# ## Model Evaluation

# %%
from sklearn.metrics  import mean_squared_error

#calculate RMSE for the Linear Regression
lr_rmse = np.sqrt(mean_squared_error(y_test,lr_preds))

#calculate RMSE for the Random Forest (default)
rf_rmse = np.sqrt(mean_squared_error(y_test,rf_preds))

# Calculate RMSE for tuned Random Forest
rf_tuned_preds          = random_search.best_estimator_.predict(X_test)
rf_tuned_rmse           = np.sqrt(mean_squared_error(y_test, rf_tuned_preds))
rf_tuned_training_preds = random_search.best_estimator_.predict(X_train)
r2_tuned_training       = r2_score(y_train, rf_tuned_training_preds)
rf_tuned_mae            = mean_absolute_error(y_test, rf_tuned_preds)
rf_tuned_r2             = r2_score(y_test, rf_tuned_preds)

# Create a DataFrame to consolidate results
results = pd.DataFrame({
    'Model': ['Linear Regression', 'Random Forest (default)', 'Random Forest (tuned)'],
    'R2': [lr_r2_testing, rf_r2_testing, rf_tuned_r2],
    'Training R2': [lr_r2_training, rf_r2_training, r2_tuned_training],
    'MAE': [lr_mae, rf_mae, rf_tuned_mae],
    'RMSE': [lr_rmse, rf_rmse, rf_tuned_rmse]
})

print(results)
# Out:
#                      Model        R2  Training R2       MAE      RMSE
# 0        Linear Regression  0.739794     0.723677  0.536178  0.676032
# 1  Random Forest (default)  0.878017     0.980907  0.346502  0.462870
# 2    Random Forest (tuned)  0.870643     0.968082  0.357810  0.476655

# %% [markdown]
# ## Save The Model

# %%
import joblib
joblib.dump(rf_pipeline, 'Mental_Health_Model.pkl')
# Out:
# ['Mental_Health_Model.pkl']

# %%
df.columns.tolist()
# Out:
# ['Age',
#  'Gender',
#  'Country',
#  'Academic_Level',
#  'Most_Used_Platform',
#  'Purpose_Of_Use',
#  'Avg_Daily_Usage_Hours',
#  'Daily_Unlocks',
#  'Study_Hours',
#  'Physical_Activity_Hours',
#  'Sleep_Hours_Per_Night',
#  'Stress_Level',
#  'Mental_Health_Score',
#  'Grouped_Country']

# %%
df.head()
# Out:
#    Age  Gender Country  ... Stress_Level Mental_Health_Score Grouped_Country
# 0   21    Male   Other  ...       Medium                 6.8           Other
# 1   23  Female   Other  ...          Low                 7.6           Other
# 2   22    Male  Canada  ...       Medium                 7.0          Canada
# 3   18    Male   Other  ...    Very High                 5.3           Other
# 4   24  Female   Other  ...    Very High                 4.4           Other
#
# [5 rows x 14 columns]

# %%
df['Academic_Level'].unique()
# Out:
# <StringArray>
# ['Undergraduate', 'Graduate', 'High School']
# Length: 3, dtype: str

# %%
df['Most_Used_Platform'].unique()
# Out:
# <StringArray>
# [ 'Facebook',  'LinkedIn', 'Instagram',  'Snapchat',   'Twitter',   'YouTube',
#     'TikTok',      'LINE', 'KakaoTalk', 'VKontakte',  'WhatsApp',    'WeChat']
# Length: 12, dtype: str

# %%
df['Purpose_Of_Use'].unique()
# Out:
# <StringArray>
# ['Networking', 'Education', 'Entertainment', 'News']
# Length: 4, dtype: str

# %%
df['Stress_Level'].unique()
# Out:
# <StringArray>
# ['Medium', 'Low', 'Very High', 'High']
# Length: 4, dtype: str
